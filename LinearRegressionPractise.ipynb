# %% [markdown]
# <a href="https://colab.research.google.com/github/bananmagdy3-crypto/Machine-Learning-NTI/blob/main/LinearRegressionPractise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/House.csv.xlsx')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
Y = df['median_house_value']
X = df.drop(columns=['median_house_value', 'ocean_proximity'])

# %%
df_encoded = pd.get_dummies(df, columns=['ocean_proximity'], drop_first=True)

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size = 0.2 , random_state = 42)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
X['total_bedrooms'] = X['total_bedrooms'].fillna(X['total_bedrooms'].median())

# %%
X['rooms_per_household'] = X['total_rooms'] / X['households']
X['bedrooms_per_room'] = X['total_bedrooms'] / X['total_rooms']
X['population_per_household'] = X['population'] / X['households']

# %%
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_520/2891402613.py in <cell line: 0>()
# ----> 1 y_pred = model.predict(X_test)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     295             Returns predicted values.
#     296         """
# --> 297         return self._decision_function(X)
#     298
#     299     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     272
#     273     def _decision_function(self, X):
# --> 274         check_is_fitted(self)
#     275
#     276         X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1755
# ...

# %%
y_pred

# %%
mse = mean_squared_error(Y_test , model.predict(X_test))
r2 = r2_score(Y_test , model.predict(X_test))

# %%
mse

# %%
r2

# %%
accuracy = model.score(X_test, Y_test)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
