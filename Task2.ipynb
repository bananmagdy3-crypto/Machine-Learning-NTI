# %% [markdown]
# <a href="https://colab.research.google.com/github/bananmagdy3-crypto/Machine-Learning-NTI/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/drive/MyDrive/Boston.csv')
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x_poly = PolynomialFeatures(degree=2).fit_transform(x)
x_poly
# Out:
# array([[1.00000000e+00, 1.00000000e+00, 6.32000000e-03, ...,
#         1.57529610e+05, 1.97656200e+03, 2.48004000e+01],
#        [1.00000000e+00, 2.00000000e+00, 2.73100000e-02, ...,
#         1.57529610e+05, 3.62766600e+03, 8.35396000e+01],
#        [1.00000000e+00, 3.00000000e+00, 2.72900000e-02, ...,
#         1.54315409e+05, 1.58310490e+03, 1.62409000e+01],
#        ...,
#        [1.00000000e+00, 5.04000000e+02, 6.07600000e-02, ...,
#         1.57529610e+05, 2.23851600e+03, 3.18096000e+01],
#        [1.00000000e+00, 5.05000000e+02, 1.09590000e-01, ...,
#         1.54802902e+05, 2.54955600e+03, 4.19904000e+01],
#        [1.00000000e+00, 5.06000000e+02, 4.74100000e-02, ...,
#         1.57529610e+05, 3.12757200e+03, 6.20944000e+01]])

# %%
model = LinearRegression()
model.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_poly)
y_pred
# Out:
# array([21.79981481, 20.53634318, 30.71439034, 32.67513096, 32.06356901,
#        26.79912049, 21.23408103, 17.73823941, 15.11170387, 21.55267122,
#        19.55624663, 21.74935804, 21.04714925, 20.79467858, 18.5581162 ,
#        20.45354445, 22.88584611, 16.79374407, 15.04266574, 17.91740397,
#        12.75567912, 16.05733409, 14.3205547 , 13.01447037, 15.13590713,
#        15.95158706, 16.33427072, 16.4385205 , 17.71059018, 19.34784567,
#        14.23048228, 15.59700199, 15.31250987, 14.23447858, 14.91233522,
#        22.12298604, 21.09688862, 22.37978515, 23.06269581, 29.31845501,
#        36.08519368, 30.98725006, 23.68717297, 24.51620907, 21.7993545 ,
#        18.32626986, 19.29985432, 18.27253962, 18.25472783, 18.18851656,
#        20.73042473, 22.1086786 , 28.35932427, 22.56234245, 19.28465485,
#        31.97268378, 27.47908444, 31.63396018, 23.06560739, 20.03487545,
#        17.86131978, 17.23122299, 23.6071008 , 25.84478248, 33.16137455,
# ...

# %%
from sklearn.metrics import r2_score
print(r2_score(y,y_pred))
# Out:
# 0.9380594218305367

# %%
mse = mean_squared_error(y,y_pred)
print(mse)
# Out:
# 5.228996117122373
